# %%
import pandas as pd
data = pd.read_csv('./ready_now_cast.csv')
data
# Out:
#        Time    growth    Economy          Mood     Price   Finance
# 0    Jan-95 -2.196206   5.200049  2.740000e-29 -9.088743 -1.954392
# 1    Feb-95 -2.364980   1.182310  1.100000e-29 -8.911641 -1.911525
# 2    Mar-95 -2.171979   0.162211  4.370000e-30 -8.719066 -1.860720
# 3    Apr-95 -1.806750   0.799172  1.750000e-30 -8.510456 -1.778586
# 4    May-95 -1.699892   0.333580  6.970000e-31 -8.281464 -1.696642
# ..      ...       ...        ...           ...       ...       ...
# 337  Feb-23  0.811917   0.564314 -7.426284e+00  0.981079  1.434399
# 338  Mar-23  0.714729   0.556326 -1.226301e+01  1.456366  1.435454
# 339  Apr-23 -1.236880   0.493918 -1.608981e+01  2.209356  1.678486
# 340  May-23 -0.540672   0.751059 -7.400438e+00  2.606879  1.783032
# 341  Jun-23 -3.520050 -12.651290  4.401231e+00  3.273916  1.753968
#
# [342 rows x 6 columns]

# %%
time_series = pd.to_datetime(data['Time'], format="%b-%y")
ts = list(time_series)
growth = list(data['growth'])
Economy = list(data['Economy'])
Mood = list(data['Mood'])
Price = list(data['Price'])
Finance = list(data['Price'])

# %%
Finance
# Out:
# [-9.088743021,
#  -8.911641288,
#  -8.719065567,
#  -8.510456333,
#  -8.281463926,
#  -8.020310033,
#  -7.751448702,
#  -7.465492029,
#  -7.180680114,
#  -6.893261526,
#  -6.604140631,
#  -6.310529818,
#  -6.015538485,
#  -5.735593839,
#  -5.457471744,
#  -5.17072766,
#  -4.874839811,
#  -4.582556742,
#  -4.288471327,
#  -3.993267793,
#  -3.691071059,
#  -3.390862213,
#  -3.196148631,
#  -3.026033323,
#  -2.669532923,
#  -2.688045379,
#  -2.383196733,
#  -2.282629168,
#  -2.191739865,
#  -1.783293403,
#  -1.629322531,
#  -1.467199208,
#  -1.260772437,
#  -1.262454544,
#  -1.169433303,
#  -0.990911099,
#  -0.738854705,
#  0.134421793,
#  0.370205572,
#  0.665950378,
#  1.255111987,
#  1.512543452,
#  1.744493097,
#  2.15987127,
#  1.579252959,
#  2.176171665,
#  2.393803193,
#  2.206305574,
#  2.329109939,
#  2.223145034,
#  2.238995495,
#  2.034711893,
#  1.77935027,
#  1.939332643,
#  1.4163544,
#  1.161090522,
#  1.245542866,
#  0.715230087,
#  0.891561055,
#  0.539268397,
# ...
